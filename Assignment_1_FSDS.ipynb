# %% [markdown]
# # 1. In the below elements which of them are values or an expression? eg:- values can be ?
# integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6 ?
#
# ANSWER- Values are:-'hello',-87.8,6.
#         Expression are:-*,-,/,+.
#
#
# # 2. What is the difference between string and variable?
#
# ANSWER-The set of characters is known as string.In python programming language is represented by single quote '' or double quote "".Example-> "hello" ,'HELLO'.
# programming example->print("ineuron"), print('Ineuron') ->o/p ineuron
#                                                              Ineuron.
#
#  Which store something in it is knowm as variable,or in simple words you can say it like a container.
#  In programming languages,variables are statically typed.IN python we have not to take care of declare and defined a variable in advanced as other programming languages.To create a variable,you just to need assign it a value and use it,the assignment is done by single equals sign =.
#  Example-> n=10 m="ineuron"  and then print it by using print function ,print(n) o/p-> 10.
#
#
#  # 3. Describe three different data types?
#
#  ANSWER-In programming languages data type is an important concept.Variable can store data of different types and different types do different things.
#  i) X="sanjay"  -> its a String data type which returns you only string values.It's a collection of unicode characters.
#  ii) X=45  ->its a Interger data type which returns you integer values only.It's a whole numbers in programming.
#  iii)X=80.03 -> is's a Float data type which returns you only float values.It's a numeric data type.
#
#
#  # 4. What is an expression made up of? What do all expressions do?
#
#  ANSWER-An expression is a combination of operators and operands that is interpreted to produce some other value in programming.The operator indicate what action or operation to perform and operand are the variable or constants on which operators works.
#  Example-> X+Y ,where X,Y are operand and + is operator.
#
#                operators   syntax   functioning
#
#            i)   +           X+Y       Addition
#            ii)  -           X-Y       Subtraction
#            iii) *           X*Y       Multiplication
#            iv)  /           X/Y       Division
#            v)  %            X%Y       Remainder
#            vi) //           X//Y      Quotient
#            vii) **          X**Y      Exponentiation
#
#
#
#
#  # 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
#  Answer-Statements represent an action or command.It is not evaluate something and cannot print the result.e.g->if,for,def,class and so on.
#
#  Expression is something that gives a values and can be printed out.e.g->print(10*2).
#
#
# # 6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1 ?
#
# Answer- bacon = 23
#
#
# # 7. What should the values of the following two terms be?
# 'spam'+'spamspam'
# 'spam'* 3
#
# Answer- Both gives same result is 'spamspamspam'
#
#
# # 8. Why is eggs a valid variable name while 100 is invalid?
#
# Answer- A variable name must be start with a letter or the underscore character.A variable cannot start with number,variable only contains alpha-numeric characters and underscores(A-Z,0-9,_).
# thats why egg is valid variable name or 100 is not valid .
# if we want to make 100 as a valid variable name then do _100_. e.g-> _100_=10
#                                                                       print(_100_)  ->o/p: 10
#
#
# # 9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Answer- The init(),float(),str() functions will evaluate to the integer,floating-point numberand string versions of value passed to them.
#
#
# # 10. Why does this expression cause an error? How can you fix it?
# 'I have eaten' + 99 + 'burritos'
#
# Answer- This error due to concatenate string with integer,which is not possible.If we want to fix this error we have to do typecasting.
#
# 'I have eaten'+str(99)+'burritos'   ->o/p: 'I have eaten99burritos'
#
#
#
#     ###################################################################
